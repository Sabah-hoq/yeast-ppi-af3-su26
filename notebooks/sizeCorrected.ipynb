# %%
from pathlib import Path
import polars as pl
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
repo_root = Path.cwd().resolve()
for candidate in [repo_root, repo_root.parent]:
    if (candidate / "data").exists():
        data_dir = candidate / "data"
        break
else:
    raise FileNotFoundError("Unable to find the 'data' directory. Set the working directory to the yeast repo root.")


confident = data_dir / "summary_confidences.parquet"
confident = pl.scan_parquet(str(confident))

pairs = data_dir / "summary_pairs.parquet"
pairs = pl.scan_parquet(str(pairs))

# %%
pairs.collect().head()
# Out:
# shape: (5, 105)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ pair_ids  ┆ name      ┆ batch_id  ┆ pool_id   ┆ … ┆ biogrid:O ┆ biogrid:O ┆ biogrid:a ┆ biogrid: │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ rganism   ┆ rganism   ┆ f3_id1    ┆ af3_id2  │
# │ list[str] ┆ str       ┆ str       ┆ str       ┆   ┆ Name      ┆ Name      ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ Interact… ┆ Interact… ┆ str       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ ---       ┆ ---       ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "p39985"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "p53107"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q02648"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q03533"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q08023"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
sizeCoreceted = (pairs.collect())["chain_pair_iptm_mean_corrected"]

sizeCoreceted.describe()
# Out:
# shape: (9, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ value      │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 7.631089e6 │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 0.007741   │
# │ std        ┆ 0.019879   │
# │ min        ┆ -0.006037  │
# │ 25%        ┆ 0.001281   │
# │ 50%        ┆ 0.003861   │
# │ 75%        ┆ 0.007415   │
# │ max        ┆ 0.796704   │
# └────────────┴────────────┘

# %%
#Histogram
fig, ax = plt.subplots()
plt.hist(sizeCoreceted, bins=100000, color='teal', edgecolor='black', alpha=0.5)
ax.ticklabel_format(style='plain', axis='y')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xlim(-0.015, 0.8)
# Display the plot
plt.show()

# %%
threshold = 0.55
chunk_size = 500000 

# The line below won't run... kernal crashes 
# pairs['z_score'] = stats.zscore(pairs.collect())["chain_pair_iptm_mean_corrected"]

# %%
cutoff = np.percentile((pairs.collect())["chain_pair_iptm_mean_corrected"], 75)

# %%
top_edges = pairs.filter(pl.col("chain_pair_iptm_mean_corrected") >= 0)
# top_edges.to_csv("top_1_percent_edges.csv", index=False)
print(len(top_edges.collect()))
print(top_edges.collect().head())
# Out:
# 6473861
# shape: (5, 105)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ pair_ids  ┆ name      ┆ batch_id  ┆ pool_id   ┆ … ┆ biogrid:O ┆ biogrid:O ┆ biogrid:a ┆ biogrid: │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ rganism   ┆ rganism   ┆ f3_id1    ┆ af3_id2  │
# │ list[str] ┆ str       ┆ str       ┆ str       ┆   ┆ Name      ┆ Name      ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ Interact… ┆ Interact… ┆ str       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ ---       ┆ ---       ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "p39985"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "p53107"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q02648"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q03533"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p39985" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "p53107"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
top_edges = pairs.filter(pl.col("chain_pair_iptm_mean_corrected") >= cutoff)
# top_edges.to_csv("top_1_percent_edges.csv", index=False)
print(len(top_edges.collect()))
print(top_edges.collect().head())
# Out:
# 1908324
# shape: (5, 105)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ pair_ids  ┆ name      ┆ batch_id  ┆ pool_id   ┆ … ┆ biogrid:O ┆ biogrid:O ┆ biogrid:a ┆ biogrid: │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ rganism   ┆ rganism   ┆ f3_id1    ┆ af3_id2  │
# │ list[str] ┆ str       ┆ str       ┆ str       ┆   ┆ Name      ┆ Name      ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ Interact… ┆ Interact… ┆ str       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ ---       ┆ ---       ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ["p32528" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q03533"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p39985" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q03533"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p53107" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q02648"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["p53107" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q08023"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# │ ["q02648" ┆ 000043c11 ┆ 26.03/eul ┆ p32528_p3 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ,         ┆ bb7cccdb7 ┆ er-std-rt ┆ 9985_p531 ┆   ┆           ┆           ┆           ┆          │
# │ "q03533"] ┆ 632f3ee98 ┆ x_pro_600 ┆ 07_q02648 ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ea1…      ┆ 0-r…      ┆ _q0…      ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Can we threshold the corrected iPTM scores? The authors recommended that. What does the distribution of corrected scores look like and is there an obvious cutoff?
# If we apply a threshold, we can avoid dealing with negative scores and the scores will be more SPRAS compatible.
# We can have small magnitude values
(top_edges.collect())["chain_pair_iptm_mean_corrected"].describe()
# Out:
# shape: (9, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ value      │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 1.908324e6 │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 0.023645   │
# │ std        ┆ 0.034956   │
# │ min        ┆ 0.007415   │
# │ 25%        ┆ 0.009559   │
# │ 50%        ┆ 0.013488   │
# │ 75%        ┆ 0.022959   │
# │ max        ┆ 0.796704   │
# └────────────┴────────────┘

# %%
fig, ax = plt.subplots()
plt.hist((top_edges.collect())["chain_pair_iptm_mean_corrected"], bins=100000, color='teal', edgecolor='black', alpha=0.5)
ax.ticklabel_format(style='plain', axis='y')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xlim(0, 0.8)
# Display the plot
plt.show()

# %%
cutoff2 = np.percentile((top_edges.collect())["chain_pair_iptm_mean_corrected"], 75)
top_edges2 = top_edges.filter(pl.col("chain_pair_iptm_mean_corrected") >= cutoff2)
print(len(top_edges2.collect()))
# Out:
# 477087

# %%
fig, ax = plt.subplots()
plt.hist((top_edges2.collect())["chain_pair_iptm_mean_corrected"], bins=100000, color='teal', edgecolor='black', alpha=0.5)
ax.ticklabel_format(style='plain', axis='y')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xlim(0, 0.8)
# Display the plot
plt.show()

# %%
(top_edges2.collect())["chain_pair_iptm_mean_corrected"].describe()
# Out:
# shape: (9, 2)
# ┌────────────┬──────────┐
# │ statistic  ┆ value    │
# │ ---        ┆ ---      │
# │ str        ┆ f64      │
# ╞════════════╪══════════╡
# │ count      ┆ 477087.0 │
# │ null_count ┆ 0.0      │
# │ mean       ┆ 0.057546 │
# │ std        ┆ 0.057486 │
# │ min        ┆ 0.022959 │
# │ 25%        ┆ 0.028289 │
# │ 50%        ┆ 0.03772  │
# │ 75%        ┆ 0.061053 │
# │ max        ┆ 0.796704 │
# └────────────┴──────────┘

# %%
cutoff3 = np.percentile((top_edges2.collect())["chain_pair_iptm_mean_corrected"], 75)
top_edges3 = top_edges2.filter(pl.col("chain_pair_iptm_mean_corrected") >= cutoff3)
print(len(top_edges3.collect()))
# Out:
# 119273

# %%
fig, ax = plt.subplots()
plt.hist((top_edges3.collect())["chain_pair_iptm_mean_corrected"], bins=50000, color='teal', edgecolor='black', alpha=0.5)
ax.ticklabel_format(style='plain', axis='y')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xlim(0, 0.8)
# Display the plot
plt.show()

# %%
(top_edges3.collect())["chain_pair_iptm_mean_corrected"].describe()
# Out:
# shape: (9, 2)
# ┌────────────┬──────────┐
# │ statistic  ┆ value    │
# │ ---        ┆ ---      │
# │ str        ┆ f64      │
# ╞════════════╪══════════╡
# │ count      ┆ 119273.0 │
# │ null_count ┆ 0.0      │
# │ mean       ┆ 0.125081 │
# │ std        ┆ 0.082685 │
# │ min        ┆ 0.061053 │
# │ 25%        ┆ 0.074009 │
# │ 50%        ┆ 0.095835 │
# │ 75%        ┆ 0.142596 │
# │ max        ┆ 0.796704 │
# └────────────┴──────────┘

# %%
## Min and Max Values 
max = (top_edges3.collect())["chain_pair_iptm_mean_corrected"].max()
min = (top_edges3.collect())["chain_pair_iptm_mean_corrected"].min()
x = (top_edges3.collect())["chain_pair_iptm_mean_corrected"]

# %%
#Normalize data 
normalization = (x - min)/ (max - min)
top_edges3_normal = top_edges3.with_columns(
    (pl.col("chain_pair_iptm_mean_corrected")/max)
    )

print(len(top_edges3_normal.collect()))
print((top_edges3_normal.collect())["chain_pair_iptm_mean_corrected"].describe())
# Out:
# 119273
# shape: (9, 2)
# ┌────────────┬──────────┐
# │ statistic  ┆ value    │
# │ ---        ┆ ---      │
# │ str        ┆ f64      │
# ╞════════════╪══════════╡
# │ count      ┆ 119273.0 │
# │ null_count ┆ 0.0      │
# │ mean       ┆ 0.156998 │
# │ std        ┆ 0.103784 │
# │ min        ┆ 0.076632 │
# │ 25%        ┆ 0.092894 │
# │ 50%        ┆ 0.120289 │
# │ 75%        ┆ 0.178982 │
# │ max        ┆ 1.0      │
# └────────────┴──────────┘

# %%
fig, ax = plt.subplots()
plt.hist((top_edges3_normal.collect())["chain_pair_iptm_mean_corrected"], bins=50000, color='teal', edgecolor='black', alpha=0.5)
ax.ticklabel_format(style='plain', axis='y')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xlim(0, 1.1)
# Display the plot
plt.show()

# %%
# Saving file in spras format using final_comp,csv
ready_file = top_edges3_normal.select([
    pl.col("chain_pair_iptm_mean_corrected").alias("weight"),
    pl.col("af3_id1").alias("protein1"),
    pl.col("af3_id2").alias("protein2"),
])

ready_file = ready_file.with_columns(
        pl.col("protein1").str.to_uppercase(),
        pl.col("protein2").str.to_uppercase()
    )

ready_file = ready_file.with_columns(direction=pl.lit("U"))
ready_file = ready_file.select(["protein1","protein2","weight","direction"])

print(ready_file.collect().head())
# Out:
# shape: (5, 4)
# ┌──────────┬──────────┬──────────┬───────────┐
# │ protein1 ┆ protein2 ┆ weight   ┆ direction │
# │ ---      ┆ ---      ┆ ---      ┆ ---       │
# │ str      ┆ str      ┆ f64      ┆ str       │
# ╞══════════╪══════════╪══════════╪═══════════╡
# │ P31382   ┆ Q12680   ┆ 0.078302 ┆ U         │
# │ P34110   ┆ Q12680   ┆ 0.24704  ┆ U         │
# │ P24868   ┆ P35203   ┆ 0.117636 ┆ U         │
# │ P24868   ┆ P38116   ┆ 0.157079 ┆ U         │
# │ P32911   ┆ P36532   ┆ 0.226303 ┆ U         │
# └──────────┴──────────┴──────────┴───────────┘

# %%
Path("../outputs/spras").mkdir(parents=True, exist_ok=True)
ready_file.collect().write_csv("../outputs/spras/yeast_spras.txt", include_header=False)
